# %%
import pyes
import json

def pp(o): 
    print json.dumps(o, indent=1)

host = '114.32.24.166:9200'

fid1 = '139624776093433'
fid2 = '1448357445384692'

def aa(fid):
    conn = pyes.es.ES(host)
    tq = pyes.query.TermQuery(field="fid", value=fid)
    tagg = pyes.aggs.TermsAgg('pid', field= 'fid_pid')
    qsearch = pyes.query.Search(tq) 
    qsearch.agg.add(tagg) 
    result = conn.search(query=qsearch , indices='facebook_nested' , doc_types='comment')
    #print json.dumps(result.aggs,indent=2) 
    for fidpid_summary in result.aggs["pid"]["buckets"]:
        print fid + ',' + str(fidpid_summary["doc_count"])

aa(fid1)
aa(fid2)
# Out:
# NotImplementedErrorTraceback (most recent call last)
# <ipython-input-1-c4d160c0933d> in <module>()
#      21         print fid + ',' + str(fidpid_summary["doc_count"])
#      22
# ---> 23 aa(fid1)
#      24 aa(fid2)
#
# <ipython-input-1-c4d160c0933d> in aa(fid)
#      18     result = conn.search(query=qsearch , indices='facebook_nested' , doc_types='comment')
#      19     #print json.dumps(result.aggs,indent=2)
# ---> 20     for fidpid_summary in result.aggs["pid"]["buckets"]:
#      21         print fid + ',' + str(fidpid_summary["doc_count"])
#      22
#
# /opt/conda/lib/python2.7/site-packages/pyes/es.pyc in aggs(self)
#    1496     def aggs(self):
#    1497         if self._results is None:
# -> 1498             self._do_search()
#    1499         return self._aggs
#    1500
#
# /opt/conda/lib/python2.7/site-packages/pyes/es.pyc in _do_search(self, auto_increment)
#    1427                 self.start += self.chuck_size
#    1428
# -> 1429             self._results = self._search_raw(self.start, self.chuck_size)
#    1430
#    1431             do_scan = self.query_params.pop("search_type", None) == "scan"
#
# /opt/conda/lib/python2.7/site-packages/pyes/es.pyc in _search_raw(self, start, size)
#    1670
#    1671         return self.connection.search_raw(self.search, indices=self.indices,
# -> 1672                                           doc_types=self.doc_types, headers=self.headers, **query_params)
#    1673
#    1674     def get_suggested_texts(self):
#
# /opt/conda/lib/python2.7/site-packages/pyes/es.pyc in search_raw(self, query, indices, doc_types, headers, **query_params)
#    1015             query = query.search()
#    1016         if isinstance(query, Search):
# -> 1017             query = query.serialize()
#    1018         body = self._encode_query(query)
#    1019         path = self._make_path(indices, doc_types, "_search")
#
# /opt/conda/lib/python2.7/site-packages/pyes/query.pyc in serialize(self)
#     241             res['facets'] = self.facet.serialize()
#     242         if self.agg.aggs:
# --> 243             res['aggs'] = self.agg.serialize()
#     244         if self.rescore:
#     245             res['rescore'] = self.rescore.serialize()
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in serialize(self)
#      19         res = {}
#      20         for agg in self.aggs:
# ---> 21             res.update(agg.serialize())
#      22         return res
#      23
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in serialize(self)
#      66
#      67     def serialize(self):
# ---> 68         data = super(BucketAgg, self).serialize()
#      69         sub_data = {}
#      70         if self.sub_aggs is not None:
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in serialize(self)
#      34
#      35     def serialize(self):
# ---> 36         data = {self._internal_name: self._serialize()}
#      37         if self.scope is not None:
#      38             data["scope"] = self.scope
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in _serialize(self)
#      48
#      49     def _serialize(self):
# ---> 50         raise NotImplementedError
#      51
#      52     @property
#
# NotImplementedError:

# %%
def bb(fid):
    conn = pyes.es.ES(host)
    tq = pyes.query.TermQuery(field="fid", value=fid)
    #tagg = pyes.aggs.TermsAgg('pid', field= 'fid_pid')
    DHAgg = pyes.aggs.DateHistogramAgg('month' ,field='created_time', interval='month',sub_aggs=[])
    tagg = pyes.aggs.TermsAgg('pid', field= 'fid_pid')
    DHAgg.sub_aggs.append(tagg) 
    qsearch = pyes.query.Search(tq) 
    qsearch.agg.add(DHAgg) 
    result = conn.search(query=qsearch , indices='facebook_nested' , doc_types='comment')
    print json.dumps(result.aggs,indent=2) 
bb(fid2)
# Out:
# NotImplementedErrorTraceback (most recent call last)
# <ipython-input-2-15362f7bb1da> in <module>()
#      10     result = conn.search(query=qsearch , indices='facebook_nested' , doc_types='comment')
#      11     print json.dumps(result.aggs,indent=2)
# ---> 12 bb(fid2)
#
# <ipython-input-2-15362f7bb1da> in bb(fid)
#       9     qsearch.agg.add(DHAgg)
#      10     result = conn.search(query=qsearch , indices='facebook_nested' , doc_types='comment')
# ---> 11     print json.dumps(result.aggs,indent=2)
#      12 bb(fid2)
#
# /opt/conda/lib/python2.7/site-packages/pyes/es.pyc in aggs(self)
#    1496     def aggs(self):
#    1497         if self._results is None:
# -> 1498             self._do_search()
#    1499         return self._aggs
#    1500
#
# /opt/conda/lib/python2.7/site-packages/pyes/es.pyc in _do_search(self, auto_increment)
#    1427                 self.start += self.chuck_size
#    1428
# -> 1429             self._results = self._search_raw(self.start, self.chuck_size)
#    1430
#    1431             do_scan = self.query_params.pop("search_type", None) == "scan"
#
# /opt/conda/lib/python2.7/site-packages/pyes/es.pyc in _search_raw(self, start, size)
#    1670
#    1671         return self.connection.search_raw(self.search, indices=self.indices,
# -> 1672                                           doc_types=self.doc_types, headers=self.headers, **query_params)
#    1673
#    1674     def get_suggested_texts(self):
#
# /opt/conda/lib/python2.7/site-packages/pyes/es.pyc in search_raw(self, query, indices, doc_types, headers, **query_params)
#    1015             query = query.search()
#    1016         if isinstance(query, Search):
# -> 1017             query = query.serialize()
#    1018         body = self._encode_query(query)
#    1019         path = self._make_path(indices, doc_types, "_search")
#
# /opt/conda/lib/python2.7/site-packages/pyes/query.pyc in serialize(self)
#     241             res['facets'] = self.facet.serialize()
#     242         if self.agg.aggs:
# --> 243             res['aggs'] = self.agg.serialize()
#     244         if self.rescore:
#     245             res['rescore'] = self.rescore.serialize()
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in serialize(self)
#      19         res = {}
#      20         for agg in self.aggs:
# ---> 21             res.update(agg.serialize())
#      22         return res
#      23
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in serialize(self)
#      71             for sub_agg in self.sub_aggs:
#      72                 if isinstance(sub_agg, Agg):
# ---> 73                     sub_data.update(sub_agg.serialize())
#      74                 else:
#      75                     raise RuntimeError("Invalid Agg: Only Stats-Aggregations allowed as Sub-Aggregations")
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in serialize(self)
#      66
#      67     def serialize(self):
# ---> 68         data = super(BucketAgg, self).serialize()
#      69         sub_data = {}
#      70         if self.sub_aggs is not None:
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in serialize(self)
#      34
#      35     def serialize(self):
# ---> 36         data = {self._internal_name: self._serialize()}
#      37         if self.scope is not None:
#      38             data["scope"] = self.scope
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in _serialize(self)
#      48
#      49     def _serialize(self):
# ---> 50         raise NotImplementedError
#      51
#      52     @property
#
# NotImplementedError:

# %%
import numpy as np
import pandas as pd

from bokeh.plotting import figure, show, output_file

# generate some synthetic time series for six different categories
cats = list("abcdef")
yy = np.random.randn(2000)
g = np.random.choice(cats, 2000)
for i, l in enumerate(cats):
    yy[g == l] += i // 2
df = pd.DataFrame(dict(score=yy, group=g))

# find the quartiles and IQR for each category
groups = df.groupby('group')
q1 = groups.quantile(q=0.25)
q2 = groups.quantile(q=0.5)
q3 = groups.quantile(q=0.75)
iqr = q3 - q1
upper = q3 + 1.5*iqr
lower = q1 - 1.5*iqr

# find the outliers for each category
def outliers(group):
    cat = group.name
    return group[(group.score > upper.loc[cat]['score']) | (group.score < lower.loc[cat]['score'])]['score']
out = groups.apply(outliers).dropna()

# prepare outlier data for plotting, we need coordinates for every outlier.
if not out.empty:
    outx = []
    outy = []
    for cat in cats:
        # only add outliers if they exist
        if not out.loc[cat].empty:
            for value in out[cat]:
                outx.append(cat)
                outy.append(value)

p = figure(tools="save", background_fill_color="#EFE8E2", title="", x_range=cats)

# if no outliers, shrink lengths of stems to be no longer than the minimums or maximums
qmin = groups.quantile(q=0.00)
qmax = groups.quantile(q=1.00)
upper.score = [min([x,y]) for (x,y) in zip(list(qmax.loc[:,'score']),upper.score)]
lower.score = [max([x,y]) for (x,y) in zip(list(qmin.loc[:,'score']),lower.score)]

# stems
p.segment(cats, upper.score, cats, q3.score, line_width=2, line_color="black")
p.segment(cats, lower.score, cats, q1.score, line_width=2, line_color="black")

# boxes
p.rect(cats, (q3.score+q2.score)/2, 0.7, q3.score-q2.score,
    fill_color="#E08E79", line_width=2, line_color="black")
p.rect(cats, (q2.score+q1.score)/2, 0.7, q2.score-q1.score,
    fill_color="#3B8686", line_width=2, line_color="black")

# whiskers (almost-0 height rects simpler than segments)
p.rect(cats, lower.score, 0.2, 0.01, line_color="black")
p.rect(cats, upper.score, 0.2, 0.01, line_color="black")

# outliers
if not out.empty:
    p.circle(outx, outy, size=6, color="#F38630", fill_alpha=0.6)

p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = "white"
p.grid.grid_line_width = 2
p.xaxis.major_label_text_font_size="12pt"

output_file("boxplot.html", title="boxplot.py example")

show(p)

# %%
out
# Out:
# group
# a      219    -3.206570
#        539    -2.812082
# b      1453    3.204931
# c      290    -1.365667
#        326    -1.796441
#        346    -1.423719
#        407    -1.981157
#        745    -1.403017
#        1053   -1.729632
#        1214    3.714630
#        1307    3.887610
#        1680    3.536521
#        1811    3.970536
#        1971   -1.419065
# d      1126   -2.293895
# e      185    -1.030660
#        598    -0.859001
#        854     4.558474
#        1014    4.908851
#        1127   -0.689201
# f      1239    5.164661
#        1878    4.886821
# Name: score, dtype: float64

# %%
groups

# %%
df
# Out:
#      group     score
# 0        d  0.895515
# 1        d  2.143753
# 2        b -0.045541
# 3        c  1.494079
# 4        f  1.920855
# 5        d  0.635777
# 6        c  0.171151
# 7        a -0.397809
# 8        a  1.125417
# 9        b  0.736720
# 10       c  0.849866
# 11       e  1.914690
# 12       f  1.782032
# 13       e  2.263361
# 14       c  0.664424
# 15       d  1.223352
# 16       c  1.662838
# 17       a -1.454621
# 18       e  1.850853
# 19       b -1.018600
# 20       e  4.327310
# 21       f  3.026903
# 22       e  2.382232
# 23       d  0.934422
# 24       d -0.121672
# 25       b  0.136140
# 26       b  2.422145
# 27       a  0.939924
# 28       f  0.816802
# 29       a -0.049905
# ...    ...       ...
# 1970     b  0.786081
# 1971     f  2.453128
# 1972     d  0.728730
# 1973     d  1.860734
# 1974     a  0.196554
# 1975     a -1.104808
# 1976     d  2.419386
# 1977     d  1.196932
# 1978     b -0.685614
# 1979     e  1.183510
# 1980     b -1.814006
# 1981     b  0.820158
# 1982     b -0.657391
# 1983     e  3.824588
# 1984     f  1.130788
# 1985     f  5.610779
# 1986     f  1.007179
# 1987     d  1.587219
# 1988     f  0.455772
# 1989     b -1.164396
# 1990     e  1.274981
# 1991     f  3.577405
# 1992     d  0.014453
# 1993     c  0.813361
# 1994     d  1.894526
# 1995     c -0.928895
# 1996     d  1.538034
# 1997     b -0.646818
# 1998     f  0.499859
# 1999     c -0.160107
#
# [2000 rows x 2 columns]

# %%
# %matplotlib inline

import pyes
import json
import pandas as pd
import seaborn as sns

def pp(o): 
    print json.dumps(o, indent=1)

def boxPlotFBFansPageComp(fids,host,pngFilePath,outlierFilter):
    data=[]
    for fid in fids:
        conn = pyes.es.ES(host)
        tq = pyes.query.TermQuery(field="fid", value=fid)
        tagg = pyes.aggs.TermsAgg('pid', field= 'fid_pid')
        qsearch = pyes.query.Search(tq) 
        qsearch.agg.add(tagg) 
        result = conn.search(query=qsearch , indices='facebook_nested' , doc_types='comment')
        #print json.dumps(result.aggs,indent=2) 
        for fidpid_summary in result.aggs["pid"]["buckets"]:
            #print fidpid_summary["key"] + ',' + str(fidpid_summary["doc_count"])
            if fidpid_summary["doc_count"] < outlierFilter or outlierFilter < 0:
                data.append([fidpid_summary["doc_count"],fid,fidpid_summary["key"]])

    df=pd.DataFrame(data,columns={'count','fid','fidpid'})
    sns.set(style="ticks")
    sns_plot=sns.boxplot(x="fid", y="count", data=df, palette="PRGn")
    fig=sns_plot.get_figure()
    fig.savefig(pngFilePath)

# %%
#assign the facebook fans page that you prefered
fids=['139624776093433','1448357445384692','179080912217031']

#elasticsearch repository provided by this course
host = '114.32.24.166:9200'

#output box plot PNG figure
pngFilePath="output.png"

#outlier threshold you want to filter (if you give minus ONE, none of outlier is filtered.)
outlierFilter=2000

#obtain the result and save as "pngFilePath" given from you
boxPlotFBFansPageComp(fids,host,pngFilePath,outlierFilter)
# Out:
# NotImplementedErrorTraceback (most recent call last)
# <ipython-input-9-8f3fd5144cdd> in <module>()
#      12
#      13 #obtain the result and save as "pngFilePath" given from you
# ---> 14 boxPlotFBFansPageComp(fids,host,pngFilePath,outlierFilter)
#
# <ipython-input-8-6708661065b7> in boxPlotFBFansPageComp(fids, host, pngFilePath, outlierFilter)
#      19         result = conn.search(query=qsearch , indices='facebook_nested' , doc_types='comment')
#      20         #print json.dumps(result.aggs,indent=2)
# ---> 21         for fidpid_summary in result.aggs["pid"]["buckets"]:
#      22             #print fidpid_summary["key"] + ',' + str(fidpid_summary["doc_count"])
#      23             if fidpid_summary["doc_count"] < outlierFilter or outlierFilter < 0:
#
# /opt/conda/lib/python2.7/site-packages/pyes/es.pyc in aggs(self)
#    1496     def aggs(self):
#    1497         if self._results is None:
# -> 1498             self._do_search()
#    1499         return self._aggs
#    1500
#
# /opt/conda/lib/python2.7/site-packages/pyes/es.pyc in _do_search(self, auto_increment)
#    1427                 self.start += self.chuck_size
#    1428
# -> 1429             self._results = self._search_raw(self.start, self.chuck_size)
#    1430
#    1431             do_scan = self.query_params.pop("search_type", None) == "scan"
#
# /opt/conda/lib/python2.7/site-packages/pyes/es.pyc in _search_raw(self, start, size)
#    1670
#    1671         return self.connection.search_raw(self.search, indices=self.indices,
# -> 1672                                           doc_types=self.doc_types, headers=self.headers, **query_params)
#    1673
#    1674     def get_suggested_texts(self):
#
# /opt/conda/lib/python2.7/site-packages/pyes/es.pyc in search_raw(self, query, indices, doc_types, headers, **query_params)
#    1015             query = query.search()
#    1016         if isinstance(query, Search):
# -> 1017             query = query.serialize()
#    1018         body = self._encode_query(query)
#    1019         path = self._make_path(indices, doc_types, "_search")
#
# /opt/conda/lib/python2.7/site-packages/pyes/query.pyc in serialize(self)
#     241             res['facets'] = self.facet.serialize()
#     242         if self.agg.aggs:
# --> 243             res['aggs'] = self.agg.serialize()
#     244         if self.rescore:
#     245             res['rescore'] = self.rescore.serialize()
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in serialize(self)
#      19         res = {}
#      20         for agg in self.aggs:
# ---> 21             res.update(agg.serialize())
#      22         return res
#      23
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in serialize(self)
#      66
#      67     def serialize(self):
# ---> 68         data = super(BucketAgg, self).serialize()
#      69         sub_data = {}
#      70         if self.sub_aggs is not None:
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in serialize(self)
#      34
#      35     def serialize(self):
# ---> 36         data = {self._internal_name: self._serialize()}
#      37         if self.scope is not None:
#      38             data["scope"] = self.scope
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in _serialize(self)
#      48
#      49     def _serialize(self):
# ---> 50         raise NotImplementedError
#      51
#      52     @property
#
# NotImplementedError:

# %%
import pyes
import json
import pandas as pd
import seaborn as sns
import datetime
import matplotlib.pyplot as plt


def boxPlotNumofPostPerMonth(fid,host,lowerbound,upperbound,pngFilePath):
    conn = pyes.es.ES(host)
    tq = pyes.query.TermQuery(field="fid", value=fid)
    #tagg = pyes.aggs.TermsAgg('pid', field= 'fid_pid')
    DHAgg = pyes.aggs.DateHistogramAgg('month' ,field='created_time', interval='month',sub_aggs=[])
    tagg = pyes.aggs.TermsAgg('pid', field= 'fid_pid')
    DHAgg.sub_aggs.append(tagg) 
    qsearch = pyes.query.Search(tq) 
    qsearch.agg.add(DHAgg) 
    result = conn.search(query=qsearch , indices='facebook_nested' , doc_types='comment')

    data=[]
    for r in result.aggs["month"]["buckets"]:
        for pid in r["pid"]["buckets"]:
            monthyear=datetime.datetime.strptime(r["key_as_string"], "%Y-%m-%dT%H:%M:%S.%fZ").strftime('%Y/%m')
            data.append([pid["doc_count"],monthyear,pid["key"],r["key"]])

    df=pd.DataFrame(data,columns={'date','count','fid','pid'})
    sns.set(style="ticks")
    sns_plot=sns.boxplot(x="date", y="count", data=df, palette="PRGn")
    fig=sns_plot.get_figure()
    plt.ylim(lower_bound, upper_bound)
    fig.savefig(pngFilePath)

# %%
host = '114.32.24.166:9200'
lower_bound = 0
upper_bound = 500
fid="1448357445384692"
pngFilePath="output3.png"
boxPlotNumofPostPerMonth(fid,host,lower_bound,upper_bound,pngFilePath)
# Out:
# NotImplementedErrorTraceback (most recent call last)
# <ipython-input-12-c9a103f2e55a> in <module>()
#       4 fid="1448357445384692"
#       5 pngFilePath="output3.png"
# ----> 6 boxPlotNumofPostPerMonth(fid,host,lower_bound,upper_bound,pngFilePath)
#
# <ipython-input-11-2728767b7003> in boxPlotNumofPostPerMonth(fid, host, lowerbound, upperbound, pngFilePath)
#      19
#      20     data=[]
# ---> 21     for r in result.aggs["month"]["buckets"]:
#      22         for pid in r["pid"]["buckets"]:
#      23             monthyear=datetime.datetime.strptime(r["key_as_string"], "%Y-%m-%dT%H:%M:%S.%fZ").strftime('%Y/%m')
#
# /opt/conda/lib/python2.7/site-packages/pyes/es.pyc in aggs(self)
#    1496     def aggs(self):
#    1497         if self._results is None:
# -> 1498             self._do_search()
#    1499         return self._aggs
#    1500
#
# /opt/conda/lib/python2.7/site-packages/pyes/es.pyc in _do_search(self, auto_increment)
#    1427                 self.start += self.chuck_size
#    1428
# -> 1429             self._results = self._search_raw(self.start, self.chuck_size)
#    1430
#    1431             do_scan = self.query_params.pop("search_type", None) == "scan"
#
# /opt/conda/lib/python2.7/site-packages/pyes/es.pyc in _search_raw(self, start, size)
#    1670
#    1671         return self.connection.search_raw(self.search, indices=self.indices,
# -> 1672                                           doc_types=self.doc_types, headers=self.headers, **query_params)
#    1673
#    1674     def get_suggested_texts(self):
#
# /opt/conda/lib/python2.7/site-packages/pyes/es.pyc in search_raw(self, query, indices, doc_types, headers, **query_params)
#    1015             query = query.search()
#    1016         if isinstance(query, Search):
# -> 1017             query = query.serialize()
#    1018         body = self._encode_query(query)
#    1019         path = self._make_path(indices, doc_types, "_search")
#
# /opt/conda/lib/python2.7/site-packages/pyes/query.pyc in serialize(self)
#     241             res['facets'] = self.facet.serialize()
#     242         if self.agg.aggs:
# --> 243             res['aggs'] = self.agg.serialize()
#     244         if self.rescore:
#     245             res['rescore'] = self.rescore.serialize()
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in serialize(self)
#      19         res = {}
#      20         for agg in self.aggs:
# ---> 21             res.update(agg.serialize())
#      22         return res
#      23
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in serialize(self)
#      71             for sub_agg in self.sub_aggs:
#      72                 if isinstance(sub_agg, Agg):
# ---> 73                     sub_data.update(sub_agg.serialize())
#      74                 else:
#      75                     raise RuntimeError("Invalid Agg: Only Stats-Aggregations allowed as Sub-Aggregations")
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in serialize(self)
#      66
#      67     def serialize(self):
# ---> 68         data = super(BucketAgg, self).serialize()
#      69         sub_data = {}
#      70         if self.sub_aggs is not None:
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in serialize(self)
#      34
#      35     def serialize(self):
# ---> 36         data = {self._internal_name: self._serialize()}
#      37         if self.scope is not None:
#      38             data["scope"] = self.scope
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in _serialize(self)
#      48
#      49     def _serialize(self):
# ---> 50         raise NotImplementedError
#      51
#      52     @property
#
# NotImplementedError:

# %%
host = '114.32.24.166:9200'
lower_bound = 0
upper_bound = 500
fid="179080912217031"
pngFilePath="output4.png"
boxPlotNumofPostPerMonth(fid,host,lower_bound,upper_bound,pngFilePath)
# Out:
# NotImplementedErrorTraceback (most recent call last)
# <ipython-input-23-1603baa98dbb> in <module>()
#       4 fid="179080912217031"
#       5 pngFilePath="output4.png"
# ----> 6 boxPlotNumofPostPerMonth(fid,host,lower_bound,upper_bound,pngFilePath)
#
# <ipython-input-11-2728767b7003> in boxPlotNumofPostPerMonth(fid, host, lowerbound, upperbound, pngFilePath)
#      19
#      20     data=[]
# ---> 21     for r in result.aggs["month"]["buckets"]:
#      22         for pid in r["pid"]["buckets"]:
#      23             monthyear=datetime.datetime.strptime(r["key_as_string"], "%Y-%m-%dT%H:%M:%S.%fZ").strftime('%Y/%m')
#
# /opt/conda/lib/python2.7/site-packages/pyes/es.pyc in aggs(self)
#    1496     def aggs(self):
#    1497         if self._results is None:
# -> 1498             self._do_search()
#    1499         return self._aggs
#    1500
#
# /opt/conda/lib/python2.7/site-packages/pyes/es.pyc in _do_search(self, auto_increment)
#    1427                 self.start += self.chuck_size
#    1428
# -> 1429             self._results = self._search_raw(self.start, self.chuck_size)
#    1430
#    1431             do_scan = self.query_params.pop("search_type", None) == "scan"
#
# /opt/conda/lib/python2.7/site-packages/pyes/es.pyc in _search_raw(self, start, size)
#    1670
#    1671         return self.connection.search_raw(self.search, indices=self.indices,
# -> 1672                                           doc_types=self.doc_types, headers=self.headers, **query_params)
#    1673
#    1674     def get_suggested_texts(self):
#
# /opt/conda/lib/python2.7/site-packages/pyes/es.pyc in search_raw(self, query, indices, doc_types, headers, **query_params)
#    1015             query = query.search()
#    1016         if isinstance(query, Search):
# -> 1017             query = query.serialize()
#    1018         body = self._encode_query(query)
#    1019         path = self._make_path(indices, doc_types, "_search")
#
# /opt/conda/lib/python2.7/site-packages/pyes/query.pyc in serialize(self)
#     241             res['facets'] = self.facet.serialize()
#     242         if self.agg.aggs:
# --> 243             res['aggs'] = self.agg.serialize()
#     244         if self.rescore:
#     245             res['rescore'] = self.rescore.serialize()
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in serialize(self)
#      19         res = {}
#      20         for agg in self.aggs:
# ---> 21             res.update(agg.serialize())
#      22         return res
#      23
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in serialize(self)
#      71             for sub_agg in self.sub_aggs:
#      72                 if isinstance(sub_agg, Agg):
# ---> 73                     sub_data.update(sub_agg.serialize())
#      74                 else:
#      75                     raise RuntimeError("Invalid Agg: Only Stats-Aggregations allowed as Sub-Aggregations")
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in serialize(self)
#      66
#      67     def serialize(self):
# ---> 68         data = super(BucketAgg, self).serialize()
#      69         sub_data = {}
#      70         if self.sub_aggs is not None:
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in serialize(self)
#      34
#      35     def serialize(self):
# ---> 36         data = {self._internal_name: self._serialize()}
#      37         if self.scope is not None:
#      38             data["scope"] = self.scope
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in _serialize(self)
#      48
#      49     def _serialize(self):
# ---> 50         raise NotImplementedError
#      51
#      52     @property
#
# NotImplementedError:

# %%
# %matplotlib inline

import pyes
import json
import pandas as pd
import seaborn as sns

def boxPlotFBFansPageComp(fids,host,pngFilePath,outlierFilter):
    data=[]
    for fid in fids:
        conn = pyes.es.ES(host)
        tq = pyes.query.TermQuery(field="fid", value=fid)
        tagg = pyes.aggs.TermsAgg('pid', field= 'fid_pid')
        qsearch = pyes.query.Search(tq) 
        qsearch.agg.add(tagg) 
        result = conn.search(query=qsearch , indices='facebook_nested' , doc_types='comment')
        #print json.dumps(result.aggs,indent=2) 
        for fidpid_summary in result.aggs["pid"]["buckets"]:
            #print fidpid_summary["key"] + ',' + str(fidpid_summary["doc_count"])
            if fidpid_summary["doc_count"] < outlierFilter or outlierFilter < 0:
                data.append([fidpid_summary["doc_count"],fid,fidpid_summary["key"]])

    df=pd.DataFrame(data,columns={'count','fid','fidpid'})
    sns.set(style="ticks")
    sns_plot=sns.boxplot(x="fid", y="count", data=df, palette="PRGn")
    fig=sns_plot.get_figure()
    fig.savefig(pngFilePath)

# %%
#assign the facebook fans page that you prefered
fids=['139624776093433','1448357445384692','179080912217031']

#elasticsearch repository provided by this course
host = '114.32.24.166:9200'

#output box plot PNG figure
pngFilePath="output.png"

#outlier threshold you want to filter (if you give minus ONE, none of outlier is filtered.)
outlierFilter=2000

#obtain the result and save as "pngFilePath" given from you
boxPlotFBFansPageComp(fids,host,pngFilePath,outlierFilter)
# Out:
# NotImplementedErrorTraceback (most recent call last)
# <ipython-input-15-8f3fd5144cdd> in <module>()
#      12
#      13 #obtain the result and save as "pngFilePath" given from you
# ---> 14 boxPlotFBFansPageComp(fids,host,pngFilePath,outlierFilter)
#
# <ipython-input-14-25809658a92e> in boxPlotFBFansPageComp(fids, host, pngFilePath, outlierFilter)
#      16         result = conn.search(query=qsearch , indices='facebook_nested' , doc_types='comment')
#      17         #print json.dumps(result.aggs,indent=2)
# ---> 18         for fidpid_summary in result.aggs["pid"]["buckets"]:
#      19             #print fidpid_summary["key"] + ',' + str(fidpid_summary["doc_count"])
#      20             if fidpid_summary["doc_count"] < outlierFilter or outlierFilter < 0:
#
# /opt/conda/lib/python2.7/site-packages/pyes/es.pyc in aggs(self)
#    1496     def aggs(self):
#    1497         if self._results is None:
# -> 1498             self._do_search()
#    1499         return self._aggs
#    1500
#
# /opt/conda/lib/python2.7/site-packages/pyes/es.pyc in _do_search(self, auto_increment)
#    1427                 self.start += self.chuck_size
#    1428
# -> 1429             self._results = self._search_raw(self.start, self.chuck_size)
#    1430
#    1431             do_scan = self.query_params.pop("search_type", None) == "scan"
#
# /opt/conda/lib/python2.7/site-packages/pyes/es.pyc in _search_raw(self, start, size)
#    1670
#    1671         return self.connection.search_raw(self.search, indices=self.indices,
# -> 1672                                           doc_types=self.doc_types, headers=self.headers, **query_params)
#    1673
#    1674     def get_suggested_texts(self):
#
# /opt/conda/lib/python2.7/site-packages/pyes/es.pyc in search_raw(self, query, indices, doc_types, headers, **query_params)
#    1015             query = query.search()
#    1016         if isinstance(query, Search):
# -> 1017             query = query.serialize()
#    1018         body = self._encode_query(query)
#    1019         path = self._make_path(indices, doc_types, "_search")
#
# /opt/conda/lib/python2.7/site-packages/pyes/query.pyc in serialize(self)
#     241             res['facets'] = self.facet.serialize()
#     242         if self.agg.aggs:
# --> 243             res['aggs'] = self.agg.serialize()
#     244         if self.rescore:
#     245             res['rescore'] = self.rescore.serialize()
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in serialize(self)
#      19         res = {}
#      20         for agg in self.aggs:
# ---> 21             res.update(agg.serialize())
#      22         return res
#      23
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in serialize(self)
#      66
#      67     def serialize(self):
# ---> 68         data = super(BucketAgg, self).serialize()
#      69         sub_data = {}
#      70         if self.sub_aggs is not None:
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in serialize(self)
#      34
#      35     def serialize(self):
# ---> 36         data = {self._internal_name: self._serialize()}
#      37         if self.scope is not None:
#      38             data["scope"] = self.scope
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in _serialize(self)
#      48
#      49     def _serialize(self):
# ---> 50         raise NotImplementedError
#      51
#      52     @property
#
# NotImplementedError:

# %%
import pyes
import json
import pandas as pd
import seaborn as sns
import datetime
import matplotlib.pyplot as plt


def boxPlotNumofPostPerMonth(fid,host,lowerbound,upperbound,pngFilePath):
    conn = pyes.es.ES(host)
    tq = pyes.query.TermQuery(field="fid", value=fid)
    #tagg = pyes.aggs.TermsAgg('pid', field= 'fid_pid')
    DHAgg = pyes.aggs.DateHistogramAgg('month' ,field='created_time', interval='month',sub_aggs=[])
    tagg = pyes.aggs.TermsAgg('pid', field= 'fid_pid')
    DHAgg.sub_aggs.append(tagg) 
    qsearch = pyes.query.Search(tq) 
    qsearch.agg.add(DHAgg) 
    result = conn.search(query=qsearch , indices='facebook_nested' , doc_types='comment')

    data=[]
    for r in result.aggs["month"]["buckets"]:
        for pid in r["pid"]["buckets"]:
            monthyear=datetime.datetime.strptime(r["key_as_string"], "%Y-%m-%dT%H:%M:%S.%fZ").strftime('%Y/%m')
            data.append([pid["doc_count"],monthyear,pid["key"],r["key"]])

    df=pd.DataFrame(data,columns={'date','count','fid','pid'})
    sns.set(style="ticks")
    sns_plot=sns.boxplot(x="date", y="count", data=df, palette="PRGn")
    fig=sns_plot.get_figure()
    plt.ylim(lower_bound, upper_bound)
    fig.savefig(pngFilePath)

# %%
host = '114.32.24.166:9200'
lower_bound = 0
upper_bound = 500
fid="139624776093433"
pngFilePath="output3.png"
boxPlotNumofPostPerMonth(fid,host,lower_bound,upper_bound,pngFilePath)
# Out:
# NotImplementedErrorTraceback (most recent call last)
# <ipython-input-28-f90b2457004b> in <module>()
#       4 fid="139624776093433"
#       5 pngFilePath="output3.png"
# ----> 6 boxPlotNumofPostPerMonth(fid,host,lower_bound,upper_bound,pngFilePath)
#
# <ipython-input-27-2728767b7003> in boxPlotNumofPostPerMonth(fid, host, lowerbound, upperbound, pngFilePath)
#      19
#      20     data=[]
# ---> 21     for r in result.aggs["month"]["buckets"]:
#      22         for pid in r["pid"]["buckets"]:
#      23             monthyear=datetime.datetime.strptime(r["key_as_string"], "%Y-%m-%dT%H:%M:%S.%fZ").strftime('%Y/%m')
#
# /opt/conda/lib/python2.7/site-packages/pyes/es.pyc in aggs(self)
#    1496     def aggs(self):
#    1497         if self._results is None:
# -> 1498             self._do_search()
#    1499         return self._aggs
#    1500
#
# /opt/conda/lib/python2.7/site-packages/pyes/es.pyc in _do_search(self, auto_increment)
#    1427                 self.start += self.chuck_size
#    1428
# -> 1429             self._results = self._search_raw(self.start, self.chuck_size)
#    1430
#    1431             do_scan = self.query_params.pop("search_type", None) == "scan"
#
# /opt/conda/lib/python2.7/site-packages/pyes/es.pyc in _search_raw(self, start, size)
#    1670
#    1671         return self.connection.search_raw(self.search, indices=self.indices,
# -> 1672                                           doc_types=self.doc_types, headers=self.headers, **query_params)
#    1673
#    1674     def get_suggested_texts(self):
#
# /opt/conda/lib/python2.7/site-packages/pyes/es.pyc in search_raw(self, query, indices, doc_types, headers, **query_params)
#    1015             query = query.search()
#    1016         if isinstance(query, Search):
# -> 1017             query = query.serialize()
#    1018         body = self._encode_query(query)
#    1019         path = self._make_path(indices, doc_types, "_search")
#
# /opt/conda/lib/python2.7/site-packages/pyes/query.pyc in serialize(self)
#     241             res['facets'] = self.facet.serialize()
#     242         if self.agg.aggs:
# --> 243             res['aggs'] = self.agg.serialize()
#     244         if self.rescore:
#     245             res['rescore'] = self.rescore.serialize()
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in serialize(self)
#      19         res = {}
#      20         for agg in self.aggs:
# ---> 21             res.update(agg.serialize())
#      22         return res
#      23
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in serialize(self)
#      71             for sub_agg in self.sub_aggs:
#      72                 if isinstance(sub_agg, Agg):
# ---> 73                     sub_data.update(sub_agg.serialize())
#      74                 else:
#      75                     raise RuntimeError("Invalid Agg: Only Stats-Aggregations allowed as Sub-Aggregations")
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in serialize(self)
#      66
#      67     def serialize(self):
# ---> 68         data = super(BucketAgg, self).serialize()
#      69         sub_data = {}
#      70         if self.sub_aggs is not None:
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in serialize(self)
#      34
#      35     def serialize(self):
# ---> 36         data = {self._internal_name: self._serialize()}
#      37         if self.scope is not None:
#      38             data["scope"] = self.scope
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in _serialize(self)
#      48
#      49     def _serialize(self):
# ---> 50         raise NotImplementedError
#      51
#      52     @property
#
# NotImplementedError:

# %%
host = '114.32.24.166:9200'
lower_bound = 0
upper_bound = 500
fid="1448357445384692"
pngFilePath="output4.png"
boxPlotNumofPostPerMonth(fid,host,lower_bound,upper_bound,pngFilePath)
# Out:
# NotImplementedErrorTraceback (most recent call last)
# <ipython-input-29-98d0c73a1e40> in <module>()
#       4 fid="1448357445384692"
#       5 pngFilePath="output4.png"
# ----> 6 boxPlotNumofPostPerMonth(fid,host,lower_bound,upper_bound,pngFilePath)
#
# <ipython-input-27-2728767b7003> in boxPlotNumofPostPerMonth(fid, host, lowerbound, upperbound, pngFilePath)
#      19
#      20     data=[]
# ---> 21     for r in result.aggs["month"]["buckets"]:
#      22         for pid in r["pid"]["buckets"]:
#      23             monthyear=datetime.datetime.strptime(r["key_as_string"], "%Y-%m-%dT%H:%M:%S.%fZ").strftime('%Y/%m')
#
# /opt/conda/lib/python2.7/site-packages/pyes/es.pyc in aggs(self)
#    1496     def aggs(self):
#    1497         if self._results is None:
# -> 1498             self._do_search()
#    1499         return self._aggs
#    1500
#
# /opt/conda/lib/python2.7/site-packages/pyes/es.pyc in _do_search(self, auto_increment)
#    1427                 self.start += self.chuck_size
#    1428
# -> 1429             self._results = self._search_raw(self.start, self.chuck_size)
#    1430
#    1431             do_scan = self.query_params.pop("search_type", None) == "scan"
#
# /opt/conda/lib/python2.7/site-packages/pyes/es.pyc in _search_raw(self, start, size)
#    1670
#    1671         return self.connection.search_raw(self.search, indices=self.indices,
# -> 1672                                           doc_types=self.doc_types, headers=self.headers, **query_params)
#    1673
#    1674     def get_suggested_texts(self):
#
# /opt/conda/lib/python2.7/site-packages/pyes/es.pyc in search_raw(self, query, indices, doc_types, headers, **query_params)
#    1015             query = query.search()
#    1016         if isinstance(query, Search):
# -> 1017             query = query.serialize()
#    1018         body = self._encode_query(query)
#    1019         path = self._make_path(indices, doc_types, "_search")
#
# /opt/conda/lib/python2.7/site-packages/pyes/query.pyc in serialize(self)
#     241             res['facets'] = self.facet.serialize()
#     242         if self.agg.aggs:
# --> 243             res['aggs'] = self.agg.serialize()
#     244         if self.rescore:
#     245             res['rescore'] = self.rescore.serialize()
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in serialize(self)
#      19         res = {}
#      20         for agg in self.aggs:
# ---> 21             res.update(agg.serialize())
#      22         return res
#      23
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in serialize(self)
#      71             for sub_agg in self.sub_aggs:
#      72                 if isinstance(sub_agg, Agg):
# ---> 73                     sub_data.update(sub_agg.serialize())
#      74                 else:
#      75                     raise RuntimeError("Invalid Agg: Only Stats-Aggregations allowed as Sub-Aggregations")
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in serialize(self)
#      66
#      67     def serialize(self):
# ---> 68         data = super(BucketAgg, self).serialize()
#      69         sub_data = {}
#      70         if self.sub_aggs is not None:
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in serialize(self)
#      34
#      35     def serialize(self):
# ---> 36         data = {self._internal_name: self._serialize()}
#      37         if self.scope is not None:
#      38             data["scope"] = self.scope
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in _serialize(self)
#      48
#      49     def _serialize(self):
# ---> 50         raise NotImplementedError
#      51
#      52     @property
#
# NotImplementedError:

# %%
host = '114.32.24.166:9200'
lower_bound = 0
upper_bound = 500
fid="179080912217031"
pngFilePath="output5.png"
boxPlotNumofPostPerMonth(fid,host,lower_bound,upper_bound,pngFilePath)
# Out:
# NotImplementedErrorTraceback (most recent call last)
# <ipython-input-30-11e8662fe70c> in <module>()
#       4 fid="179080912217031"
#       5 pngFilePath="output5.png"
# ----> 6 boxPlotNumofPostPerMonth(fid,host,lower_bound,upper_bound,pngFilePath)
#
# <ipython-input-27-2728767b7003> in boxPlotNumofPostPerMonth(fid, host, lowerbound, upperbound, pngFilePath)
#      19
#      20     data=[]
# ---> 21     for r in result.aggs["month"]["buckets"]:
#      22         for pid in r["pid"]["buckets"]:
#      23             monthyear=datetime.datetime.strptime(r["key_as_string"], "%Y-%m-%dT%H:%M:%S.%fZ").strftime('%Y/%m')
#
# /opt/conda/lib/python2.7/site-packages/pyes/es.pyc in aggs(self)
#    1496     def aggs(self):
#    1497         if self._results is None:
# -> 1498             self._do_search()
#    1499         return self._aggs
#    1500
#
# /opt/conda/lib/python2.7/site-packages/pyes/es.pyc in _do_search(self, auto_increment)
#    1427                 self.start += self.chuck_size
#    1428
# -> 1429             self._results = self._search_raw(self.start, self.chuck_size)
#    1430
#    1431             do_scan = self.query_params.pop("search_type", None) == "scan"
#
# /opt/conda/lib/python2.7/site-packages/pyes/es.pyc in _search_raw(self, start, size)
#    1670
#    1671         return self.connection.search_raw(self.search, indices=self.indices,
# -> 1672                                           doc_types=self.doc_types, headers=self.headers, **query_params)
#    1673
#    1674     def get_suggested_texts(self):
#
# /opt/conda/lib/python2.7/site-packages/pyes/es.pyc in search_raw(self, query, indices, doc_types, headers, **query_params)
#    1015             query = query.search()
#    1016         if isinstance(query, Search):
# -> 1017             query = query.serialize()
#    1018         body = self._encode_query(query)
#    1019         path = self._make_path(indices, doc_types, "_search")
#
# /opt/conda/lib/python2.7/site-packages/pyes/query.pyc in serialize(self)
#     241             res['facets'] = self.facet.serialize()
#     242         if self.agg.aggs:
# --> 243             res['aggs'] = self.agg.serialize()
#     244         if self.rescore:
#     245             res['rescore'] = self.rescore.serialize()
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in serialize(self)
#      19         res = {}
#      20         for agg in self.aggs:
# ---> 21             res.update(agg.serialize())
#      22         return res
#      23
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in serialize(self)
#      71             for sub_agg in self.sub_aggs:
#      72                 if isinstance(sub_agg, Agg):
# ---> 73                     sub_data.update(sub_agg.serialize())
#      74                 else:
#      75                     raise RuntimeError("Invalid Agg: Only Stats-Aggregations allowed as Sub-Aggregations")
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in serialize(self)
#      66
#      67     def serialize(self):
# ---> 68         data = super(BucketAgg, self).serialize()
#      69         sub_data = {}
#      70         if self.sub_aggs is not None:
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in serialize(self)
#      34
#      35     def serialize(self):
# ---> 36         data = {self._internal_name: self._serialize()}
#      37         if self.scope is not None:
#      38             data["scope"] = self.scope
#
# /opt/conda/lib/python2.7/site-packages/pyes/aggs.pyc in _serialize(self)
#      48
#      49     def _serialize(self):
# ---> 50         raise NotImplementedError
#      51
#      52     @property
#
# NotImplementedError:

# %%
import pyes
import json

def getUserPostFreqMatrix(es_address,row,column,fid):
    rc=200
    cc=200
    
    rowIndexList,colIndexList,matrix = [],[],[]
    conn=pyes.es.ES(es_address)
    tq = pyes.query.TermQuery(field="fid", value=fid)

    tagg = pyes.aggs.TermsAgg(row, field= r, sub_aggs=[]) 
    tagg1 = pyes.aggs.TermsAgg(column, field= c)  
    tagg.sub_aggs.append(tagg1) 

    qsearch = pyes.query.Search(tq) 
    qsearch.agg.add(tagg)

    rs = conn.search(query=qsearch, indices='facebook_nested' ,type="comment" )
    
    rowcount=0
    colcount=0
    for user in rs.aggs[row]['buckets']:
        if user['key']!="" and user['key'] not in rowIndexList and rowcount<rc:
            rowIndexList.append(user['key'])
            rowcount=rowcount+1

        for post in user[column]['buckets']:
            if post['key'] not in colIndexList and colcount<cc:
                colIndexList.append(post['key'])
                colcount=colcount+1

    for i in range(0,len(rowIndexList)):
        matrix.append([0.0]*len(colIndexList))

    for user in rs.aggs[row]['buckets']:
        if user["key"] in rowIndexList:
            for post in user[column]['buckets']:
                if post['key'] in colIndexList:
                    matrix[rowIndexList.index(user['key'])][colIndexList.index(post['key'])]= float(post['doc_count'])
    
    
    return {"data":matrix,"col":colIndexList,"row":rowIndexList}

# %%
es_address="114.32.24.166:9200"
row="from.id"
column="fid_pid"
fid="179080912217031"
result = getUserPostFreqMatrix(es_address,row,column,fid)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-33-98d7ceeb8bda> in <module>()
#       3 column="fid_pid"
#       4 fid="179080912217031"
# ----> 5 result = getUserPostFreqMatrix(es_address,row,column,fid)
#
# <ipython-input-32-40431973c9ae> in getUserPostFreqMatrix(es_address, row, column, fid)
#      10     tq = pyes.query.TermQuery(field="fid", value=fid)
#      11
# ---> 12     tagg = pyes.aggs.TermsAgg(row, field= r, sub_aggs=[])
#      13     tagg1 = pyes.aggs.TermsAgg(column, field= c)
#      14     tagg.sub_aggs.append(tagg1)
#
# NameError: global name 'r' is not defined

# %%
from string import letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

# Generate a large random dataset
d = pd.DataFrame(data=result["data"],
                 columns=result["col"])

# Compute the correlation matrix
corr = d.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(20, 10))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3,
            square=True, xticklabels=5, yticklabels=5,
            linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-34-6342ddbe14d9> in <module>()
#       8
#       9 # Generate a large random dataset
# ---> 10 d = pd.DataFrame(data=result["data"],
#      11                  columns=result["col"])
#      12
#
# NameError: name 'result' is not defined

# %%
result["row"]
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-35-7ebff99484d0> in <module>()
# ----> 1 result["row"]
#
# NameError: name 'result' is not defined
